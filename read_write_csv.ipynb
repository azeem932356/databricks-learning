# %%
df= spark.read.csv("/Volumes/workspace/default/raw_data/", header= True, inferSchema=True)
df.show()

# %%
df.printSchema()

# %%
#There is a another way of doing Schema

df1= spark.read\
    .option("inferSchema", True)\
    .option("header", True)\
    .option("dateFormat", "yyyy-MM-dd") \
    .csv("/Volumes/workspace/default/raw_data/")
df1.show()

# %%
# Or we we can explicitly define Schema
from pyspark.sql import functions as F, types as T

csv_schema= T.StructType([
    T.StructField("order_date", T.DateType()),
    T.StructField("country", T.StringType()),
    T.StructField("order_id", T.IntegerType()),
    T.StructField("product", T.StringType()),
    T.StructField("qty", T.IntegerType()),
    T.StructField("price", T.DoubleType())
])

df2= spark.read\
    .option("header", True)\
    .schema(csv_schema)\
    .csv("/Volumes/workspace/default/raw_data/")
df2.show()

# %%
df2.printSchema()
